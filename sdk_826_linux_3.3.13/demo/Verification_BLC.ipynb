# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
input_data = np.loadtxt('D:\Academic Folders\FYP\BLC Data\BLC_053.txt',delimiter=",")

# %%
timestamp = input_data[:,0]
initial_timestamp = timestamp[0]
timestamp = timestamp - initial_timestamp
timestamp
# Out:
# array([0.0000000e+00, 9.4000000e+01, 1.6100000e+02, ..., 1.0758781e+07,
#        1.0758815e+07, 1.0758849e+07])

# %%
input_data =
# Out:
# array([0.0000000e+00, 9.4000000e+01, 1.6100000e+02, ..., 1.0758781e+07,
#        1.0758815e+07, 1.0758849e+07])

# %%
plt.figure(figsize=(15,8))

plt.plot(timestamp, 3*input_data[:,1], c='r', label = 'Tracked Surface Variation',linewidth = 1)
plt.plot(timestamp, input_data[:,2], c='b', label = 'Reproduced Surface Variation',linewidth = 1)

plt.xlabel('Time (s)')
plt.ylabel('Position (mm)')
plt.title('Position vs Time')

plt.xlim(4e6,8e6)
#plt.ylim(0,2.5)
plt.legend()
plt.grid()

plt.show()

# %%
plt.figure(figsize=(15,8))

plt.plot(timestamp, 3*input_data[:,3], c='r', label = 'Tracked Surface Variation',linewidth = 1)
plt.plot(timestamp, -input_data[:,4], c='b', label = 'Reproduced Surface Variation',linewidth = 1)



plt.xlabel('Time (s)')
plt.ylabel('Position (mm)')
plt.title('Position vs Time')

#plt.xlim(0,10.5)
#plt.xlim(0.6,0.8)
plt.legend()
plt.grid()

plt.show()
