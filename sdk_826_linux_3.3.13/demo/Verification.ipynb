# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
input_data = np.loadtxt('F_7.txt',delimiter=",")

# %%
timestamp = input_data[:,0]
initial_timestamp = timestamp[0]
timestamp = timestamp - initial_timestamp
timestamp
# Out:
# array([0.000000e+00, 9.700000e+01, 1.580000e+02, ..., 8.981503e+06,
#        8.981531e+06, 8.981560e+06])

# %%
plt.figure(figsize=(20,10))

plt.plot(timestamp, input_data[:,3], c='r', label = 'Tracked Surface Variation',linewidth = 1)
plt.plot(timestamp, -input_data[:,4], c='b', label = 'Reproduced Surface Variation',linewidth = 1)

plt.xlabel('Time (s)')
plt.ylabel('Position (mm)')
plt.title('Position vs Time')

plt.xlim(4e6,8e6)
#plt.ylim(0,2.5)
plt.legend()
plt.grid()

plt.show()
# Out:
# /usr/lib/python3/dist-packages/IPython/core/pylabtools.py:132: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.figure(figsize=(20,10))

plt.plot(timestamp, input_data[:,1], c='r', label = 'Tracked Surface Variation',linewidth = 1)
plt.plot(timestamp, -input_data[:,2], c='b', label = 'Reproduced Surface Variation',linewidth = 1)



plt.xlabel('Time (s)')
plt.ylabel('Position (mm)')
plt.title('Position vs Time')

#plt.xlim(0,10.5)
#plt.xlim(0.6,0.8)
plt.legend()
plt.grid()

plt.show()
