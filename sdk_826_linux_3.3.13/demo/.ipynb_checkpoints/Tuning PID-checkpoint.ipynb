# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
input_data = np.loadtxt('Verification_new_51.txt',delimiter=",")

# %%
input_data
# Out:
# array([[ 5.70372894e+08,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00],
#        [ 5.70372928e+08,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00],
#        [ 5.70372954e+08,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00],
#        ...,
#        [ 5.91356060e+08, -3.00000000e+00,  7.40000000e+01,
#          2.40469600e+00],
#        [ 5.91356085e+08, -3.00000000e+00,  7.40000000e+01,
#          2.40353600e+00],
#        [ 5.91356111e+08, -3.00000000e+00,  7.40000000e+01,
#          2.40233000e+00]])

# %%
plt.figure(figsize=(20,10))
plt.plot(input_data[:,0], input_data[:,1]*0.005*10)
plt.plot(input_data[:,0], input_data[:,2]*0.005)
#plt.ylim(0,4)
#plt.xlim(-1.205e9,-1.19e9)
plt.show()
