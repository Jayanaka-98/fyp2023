# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
input_data = np.loadtxt('V_8.txt',delimiter=",")

# %%
input_data
# Out:
# array([[ 2.06151014e+09,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00],
#        [ 2.06151024e+09,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00],
#        [ 2.06151028e+09,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00],
#        ...,
#        [ 2.08387809e+09, -5.10000000e+01, -5.10000000e+02,
#         -5.08393000e-01],
#        [ 2.08387812e+09, -5.10000000e+01, -5.10000000e+02,
#         -5.08393000e-01],
#        [ 2.08387814e+09, -5.10000000e+01, -5.10000000e+02,
#         -5.08393000e-01]])

# %%
plt.figure(figsize=(20,10))
plt.plot(input_data[:,0], input_data[:,1]*0.005*19)
plt.plot(input_data[:,0], input_data[:,2]*0.005)
#plt.ylim(0,4)
#plt.xlim(-1.205e9,-1.19e9)
plt.show()
