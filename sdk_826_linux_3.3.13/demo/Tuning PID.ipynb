# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
input_data = np.loadtxt('tuning_21.txt',delimiter=",")

# %%
input_data
# Out:
# array([[ 4.19500128e+08,  0.00000000e+00,  0.00000000e+00],
#        [ 4.19500160e+08,  1.00000000e-06,  0.00000000e+00],
#        [ 4.19500185e+08,  1.00000000e-06,  0.00000000e+00],
#        ...,
#        [ 4.32975942e+08, -2.00000000e-06, -1.05000000e-04],
#        [ 4.32975955e+08, -1.00000000e-06, -1.05000000e-04],
#        [ 4.32975969e+08, -1.00000000e-06, -1.00000000e-04]])

# %%
plt.figure(figsize=(20,10))
plt.plot(input_data[:,0], input_data[:,1])
plt.plot(input_data[:,0], input_data[:,2])
#plt.ylim(0,4)
#plt.xlim(-1.205e9,-1.19e9)
plt.show()
